# %%
# Dictionary of movies

movies = [
{
"name": "Usual Suspects", 
"imdb": 7.0,
"category": "Thriller"
},
{
"name": "Hitman",
"imdb": 6.3,
"category": "Action"
},
{
"name": "Dark Knight",
"imdb": 9.0,
"category": "Adventure"
},
{
"name": "The Help",
"imdb": 8.0,
"category": "Drama"
},
{
"name": "The Choice",
"imdb": 6.2,
"category": "Romance"
},
{
"name": "Colonia",
"imdb": 7.4,
"category": "Romance"
},
{
"name": "Love",
"imdb": 6.0,
"category": "Romance"
},
{
"name": "Bride Wars",
"imdb": 5.4,
"category": "Romance"
},
{
"name": "AlphaJet",
"imdb": 3.2,
"category": "War"
},
{
"name": "Ringing Crime",
"imdb": 4.0,
"category": "Crime"
},
{
"name": "Joking muck",
"imdb": 7.2,
"category": "Comedy"
},
{
"name": "What is the name",
"imdb": 9.2,
"category": "Suspense"
},
{
"name": "Detective",
"imdb": 7.0,
"category": "Suspense"
},
{
"name": "Exam",
"imdb": 4.2,
"category": "Thriller"
},
{
"name": "We Two",
"imdb": 7.2,
"category": "Romance"
}
]

#task1
def imdb55(movie):
    if(movie["imdb"] > 5.5):
        return True
    return False

#task2
def list_imdb55(movies):
    s = []
    for i in movies:
        if(i["imdb"] > 5.5):
            s.append(i["name"])
    return s

#task3
def category(movies, category):
    s = []
    for i in movies:
        if(category == i["category"]):
            s.append(i["name"])
    return s

#task4
def avg_imdb(movies):
    s = []
    for i in movies:
        s.append(i["imdb"])
    return sum(s)/len(s)

#task5
def avg_imdb_category(movies, category):
    s = []
    for i in movies:
        if(category == i["category"]):
            s.append(i["imdb"])
    return sum(s)/len(s)


print(imdb55(movies[1]))
print(list_imdb55(movies))
print(category(movies, "Comedy"))
print(avg_imdb(movies))
print(avg_imdb_category(movies, "Romance"))
# Out:
# True
# ['Usual Suspects', 'Hitman', 'Dark Knight', 'The Help', 'The Choice', 'Colonia', 'Love', 'Joking muck', 'What is the name', 'Detective', 'We Two']
# ['Joking muck']
# 6.486666666666666
# 6.44
